# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAI
from langchain_astradb import AstraDBVectorStore
from langchain_core.documents import Document
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_text_splitters import RecursiveCharacterTextSplitter

load_dotenv()
# Out:
# True

# %%
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
model_name = "gemini-pro"

llm = GoogleGenerativeAI(model=model_name,
                         google_api_key=GOOGLE_API_KEY,
                         max_output_tokens=2048,
                         max_retries=20,
                         temperature=0)
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

# %%
llm("Hello, how are you today?")
# Out:
# 'As an AI chatbot, I don\'t have personal feelings or experiences, so I don\'t have a "today" or the capacity to feel emotions. I am designed to provide information and assist users to the best of my abilities.'

# %% [markdown]
# Ingest

# %%
from datasets import (
    load_dataset,
)

# %%
ASTRA_DB_API_ENDPOINT = os.getenv("ASTRA_DB_API_ENDPOINT")
ASTRA_DB_APPLICATION_TOKEN = os.getenv("ASTRA_DB_APPLICATION_TOKEN")
ASTRA_DB_KEYSPACE_Philo = os.getenv("ASTRA_DB_KEYSPACE_Philo")

# %%
vstore = AstraDBVectorStore(
    embedding=embeddings,
    collection_name="astra_vector_demo",
    api_endpoint=ASTRA_DB_API_ENDPOINT,
    token=ASTRA_DB_APPLICATION_TOKEN,
    namespace=ASTRA_DB_KEYSPACE_Philo,
)

# %%
philo_dataset = load_dataset("datastax/philosopher-quotes")["train"]

docs = []
for entry in philo_dataset:
    # print(entry)
    author = entry["author"]
    quote = entry["quote"]
    tags = entry["tags"]
    metadata = {"author": author, "tags": tags}

    doc = Document(page_content=f"Quote: {quote}, Author:{author}, tags:{str(tags)}", metadata=metadata)
    # print(doc)
    docs.append(doc)

# inserted_ids = vstore.add_documents(docs)
# print(f"\nInserted {len(inserted_ids)} documents.")

# %%
docs
# Out:
# [Document(page_content="Quote: True happiness comes from gaining insight and growing into your best possible self. Otherwise all you're having is immediate gratification pleasure, which is fleeting and doesn't grow you as a person., Author:aristotle, tags:knowledge", metadata={'author': 'aristotle', 'tags': 'knowledge'}),
#  Document(page_content='Quote: The roots of education are bitter, but the fruit is sweet., Author:aristotle, tags:education;knowledge', metadata={'author': 'aristotle', 'tags': 'education;knowledge'}),
#  Document(page_content='Quote: Before you heal the body you must first heal the mind, Author:aristotle, tags:ethics', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='Quote: The proof that you know something is that you are able to teach it, Author:aristotle, tags:education;knowledge', metadata={'author': 'aristotle', 'tags': 'education;knowledge'}),
#  Document(page_content='Quote: Those who are not angry at the things they should be angry at are thought to be fools, and so are those who are not angry in the right way, at the right time, or with the right persons., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: Whatever we learn to do, we learn by actually doing it; men come to be builders, for instance, by building, and harp players by playing the harp. In the same way, by doing just acts we come to be just; by doing self-controlled acts, we come to be self-controlled ; and by doing brave acts, we become brave., Author:aristotle, tags:education;knowledge', metadata={'author': 'aristotle', 'tags': 'education;knowledge'}),
#  Document(page_content='Quote: The greatest thing by far is to be a master of metaphor; it is the one thing that cannot be learned from others; and it is also a sign of genius, since a good metaphor implies an intuitive perception of the similarity of the dissimilar., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: The society that loses its grip on the past is in danger, for it produces men who know nothing but the present, and who are not aware that life had been, and could be, different from what it is., Author:aristotle, tags:history;ethics;knowledge', metadata={'author': 'aristotle', 'tags': 'history;ethics;knowledge'}),
#  Document(page_content='Quote: The man who is truly good and wise will bear with dignity whatever fortune sends, and will always make the best of his circumstances., Author:aristotle, tags:knowledge;ethics', metadata={'author': 'aristotle', 'tags': 'knowledge;ethics'}),
#  Document(page_content='Quote: The greatest of all pleasures is the pleasure of learning., Author:aristotle, tags:knowledge;education;history', metadata={'author': 'aristotle', 'tags': 'knowledge;education;history'}),
#  Document(page_content='Quote: Fortune favours the bold., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: You are what you repeatedly do, Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: The quality of life is determined by its activities., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: You are what you do repeatedly., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: Anyone who has no need of anybody but himself is either a beast or a God., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: Love is composed of a single soul inhabiting two bodies., Author:aristotle, tags:love', metadata={'author': 'aristotle', 'tags': 'love'}),
#  Document(page_content='Quote: Love well, be loved and do something of value., Author:aristotle, tags:love;ethics', metadata={'author': 'aristotle', 'tags': 'love;ethics'}),
#  Document(page_content='Quote: Philosophy begins with wonder., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: Plato is my friend, but truth is a better friend., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: At his best, man is the noblest of all animals; separated from law and justice he is the worst., Author:aristotle, tags:ethics', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='Quote: A promise made must be a promise kept., Author:aristotle, tags:ethics', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='Quote: It is better for a city to be governed by a good man than by good laws., Author:aristotle, tags:politics;ethics', metadata={'author': 'aristotle', 'tags': 'politics;ethics'}),
#  Document(page_content='Quote: Men become richer not only by increasing their existing wealth but also by decreasing their expenditure., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: Consider pleasures as they depart, not as they come., Author:aristotle, tags:ethics', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='Quote: Dignity does not consist in possessing honors, but in deserving them., Author:aristotle, tags:ethics', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='Quote: He who sees things grow from the beginning will have the best view of them., Author:aristotle, tags:knowledge;history;ethics;education', metadata={'author': 'aristotle', 'tags': 'knowledge;history;ethics;education'}),
#  Document(page_content='Quote: Happiness is the reward of virtue., Author:aristotle, tags:ethics', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='Quote: If you would understand anything, observe its beginning and its development, Author:aristotle, tags:history;knowledge', metadata={'author': 'aristotle', 'tags': 'history;knowledge'}),
#  Document(page_content='Quote: A friend is another I., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: He who hath many friends hath none., Author:aristotle, tags:ethics', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='Quote: The hand is the tool of tools., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: Good moral character is not something that we can achieve on our own. We need a culture that supports the conditions under which self-love and friendship flourish., Author:aristotle, tags:ethics', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='Quote: We give up leisure in order that we may have leisure, just as we go to war in order that we may have peace., Author:aristotle, tags:ethics', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='Quote: We must be neither cowardly nor rash but courageous., Author:aristotle, tags:ethics;knowledge', metadata={'author': 'aristotle', 'tags': 'ethics;knowledge'}),
#  Document(page_content='Quote: The true nature of anything is what it becomes at its highest., Author:aristotle, tags:knowledge', metadata={'author': 'aristotle', 'tags': 'knowledge'}),
#  Document(page_content="Quote: To give away money is an easy matter and in any man's power. But to decide to whom to give it and how large and when, and for what purpose and how, is neither in every man's power nor an easy matter., Author:aristotle, tags:knowledge;ethics;politics", metadata={'author': 'aristotle', 'tags': 'knowledge;ethics;politics'}),
#  Document(page_content="Quote: A man's happiness consists in the free exercise of his highest faculties., Author:aristotle, tags:knowledge;ethics;education", metadata={'author': 'aristotle', 'tags': 'knowledge;ethics;education'}),
#  Document(page_content='Quote: For what is the best choice for each individual is the highest it is possible for him to achieve., Author:aristotle, tags:knowledge;ethics;education', metadata={'author': 'aristotle', 'tags': 'knowledge;ethics;education'}),
#  Document(page_content='Quote: Those who act receive the prizes., Author:aristotle, tags:ethics', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='Quote: A man becomes a friend whenever being loved he loves in return., Author:aristotle, tags:love;ethics', metadata={'author': 'aristotle', 'tags': 'love;ethics'}),
#  Document(page_content='Quote: Character is that which reveals moral purpose, exposing the class of things a man chooses and avoids., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: Bad men are full of repentance., Author:aristotle, tags:ethics', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='Quote: For we do not think that we know a thing until we are acquainted with its primary conditions or first principles, and have carried our analysis as far as its simplest elements., Author:aristotle, tags:knowledge', metadata={'author': 'aristotle', 'tags': 'knowledge'}),
#  Document(page_content='Quote: Philosophy can make people sick., Author:aristotle, tags:politics', metadata={'author': 'aristotle', 'tags': 'politics'}),
#  Document(page_content='Quote: Democracy appears to be safer and less liable to revolution than oligarchy. For in oligarchies there is the double danger of the oligarchs falling out among themselves and also with the people; but in democracies there is only the danger of a quarrel with the oligarchs. No dissension worth mentioning arises among the people themselves. And we may further remark that a government which is composed of the middle class more nearly approximates to democracy than to oligarchy, and is the safest of the imperfect forms of government., Author:aristotle, tags:politics;knowledge', metadata={'author': 'aristotle', 'tags': 'politics;knowledge'}),
#  Document(page_content='Quote: Civil confusions often spring from trifles but decide great issues., Author:aristotle, tags:ethics;politics', metadata={'author': 'aristotle', 'tags': 'ethics;politics'}),
#  Document(page_content='Quote: All men by nature desire knowledge., Author:aristotle, tags:knowledge;education', metadata={'author': 'aristotle', 'tags': 'knowledge;education'}),
#  Document(page_content='Quote: But is it just then that the few and the wealthy should be the rulers? And what if they, in like manner, rob and plunder the people, - is this just?, Author:aristotle, tags:politics;ethics', metadata={'author': 'aristotle', 'tags': 'politics;ethics'}),
#  Document(page_content='Quote: Definition of tragedy: A hero destroyed by the excess of his virtues, Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: Every rascal is not a thief, but every thief is a rascal., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Quote: It is difficult to find happiness within oneself, but it is impossible to find it anywhere else., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: A high degree of intellect tends to make a man unsocial., Author:schopenhauer, tags:knowledge', metadata={'author': 'schopenhauer', 'tags': 'knowledge'}),
#  Document(page_content='Quote: It is difficult to keep quiet if you have nothing to do, Author:schopenhauer, tags:ethics', metadata={'author': 'schopenhauer', 'tags': 'ethics'}),
#  Document(page_content='Quote: The assumption that animals are without rights, and the illusion that our treatment of them has no moral significance, is a positively outrageous example of Western crudity and barbarity. Universal compassion is the only guarantee of morality., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: I observed once to Goethe that when a friend is with us we do not think the same of him as when he is away. He replied, "Yes! because the absent friend is yourself, and he exists only in your head; whereas the friend who is present has an individuality of his own, and moves according to laws of his own, which cannot always be in accordance with those which you form for yourself., Author:schopenhauer, tags:knowledge;ethics', metadata={'author': 'schopenhauer', 'tags': 'knowledge;ethics'}),
#  Document(page_content='Quote: Every man takes the limits of his own field of vision for the limits of the world., Author:schopenhauer, tags:ethics;knowledge', metadata={'author': 'schopenhauer', 'tags': 'ethics;knowledge'}),
#  Document(page_content='Quote: Thus, the task is not so much to see what no one yet has seen, but to think what nobody yet has thought about that which everybody sees., Author:schopenhauer, tags:knowledge', metadata={'author': 'schopenhauer', 'tags': 'knowledge'}),
#  Document(page_content="Quote: Pleasure is never as pleasant as we expected it to be and pain is always more painful. The pain in the world always outweighs the pleasure. If you don't believe it, compare the respective feelings of two animals, one of which is eating the other., Author:schopenhauer, tags:None", metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: at the death of every friendly soul, Author:schopenhauer, tags:history', metadata={'author': 'schopenhauer', 'tags': 'history'}),
#  Document(page_content='Quote: arises from the feeling that there is, Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: To be alone is the fate of all great mindsa fate deplored at times, but still always chosen as the less grievous of two evils., Author:schopenhauer, tags:knowledge;ethics', metadata={'author': 'schopenhauer', 'tags': 'knowledge;ethics'}),
#  Document(page_content='Quote: However, for the man who studies to gain insight, books and studies are merely rungs of the ladder on which he climbs to the summit of knowledge. As soon as a rung has raised him up one step, he leaves it behind. On the other hand, the many who study in order to fill their memory do not use the rungs of the ladder for climbing, but take them off and load themselves with them to take away, rejoicing at the increasing weight of the burden. They remain below forever, because they bear what should have bourne them., Author:schopenhauer, tags:knowledge;education', metadata={'author': 'schopenhauer', 'tags': 'knowledge;education'}),
#  Document(page_content='Quote: There is not a grain of dust, not an atom that can become nothing, yet man believes that death is the annhilation of his being., Author:schopenhauer, tags:ethics;religion', metadata={'author': 'schopenhauer', 'tags': 'ethics;religion'}),
#  Document(page_content='Quote: Human life, like all inferior goods, is covered on the outside with a false glitter; what suffers always conceals itself., Author:schopenhauer, tags:ethics', metadata={'author': 'schopenhauer', 'tags': 'ethics'}),
#  Document(page_content='Quote: Just as one spoils the stomach by overfeeding and thereby impairs the whole body, so can one overload and choke the mind by giving it too much nourishment. For the more one reads the fewer are the traces left of what one has read; the mind is like a tablet that has been written over and over. Hence it is impossible to reflect; and it is only by reflection that one can assimilate what one has read. If one reads straight ahead without pondering over it later, what has been read does not take root, but is for the most part lost., Author:schopenhauer, tags:knowledge;ethics', metadata={'author': 'schopenhauer', 'tags': 'knowledge;ethics'}),
#  Document(page_content='Quote: The highest, most varied and lasting pleasures are those of the mind., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: We seldom speak of what we have but often of what we lack., Author:schopenhauer, tags:knowledge;ethics', metadata={'author': 'schopenhauer', 'tags': 'knowledge;ethics'}),
#  Document(page_content='Quote: Patriotism is the passion of fools and the most foolish of passions., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: Truth that is naked is the most beautiful, and the simpler its expression the deeper is the impression it makes., Author:schopenhauer, tags:ethics;education', metadata={'author': 'schopenhauer', 'tags': 'ethics;education'}),
#  Document(page_content='Quote: Restlessness is the hallmark of existence., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: Men best show their character in trifles, where they are not on their guard. It is in the simplest habits, that we often see the boundless egotism which pays no regard to the feelings of others and denies nothing to itself., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content="Quote: Because Christian morality leaves animals out of account, they are at once outlawed in philosophical morals; they are mere 'things,' mere means to any ends whatsoever. They can therefore be used for vivisection, hunting, coursing, bullfights, and horse racing, and can be whipped to death as they struggle along with heavy carts of stone. Shame on such a morality that is worthy of pariahs, and that fails to recognize the eternal essence that exists in every living thing, and shines forth with inscrutable significance from all eyes that see the sun!, Author:schopenhauer, tags:None", metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: Whoever wants his judgment to be believed, should express it coolly and dispassionately; for all vehemence springs from the will. And so the judgment might be attributed to the will and not to knowledge, which by its nature is cold., Author:schopenhauer, tags:ethics', metadata={'author': 'schopenhauer', 'tags': 'ethics'}),
#  Document(page_content='Quote: Our moral virtues benefit mainly other people; intellectual virtues, on the other hand, benefit primarily ourselves; therefore the former make us universally popular, the latter unpopular., Author:schopenhauer, tags:ethics', metadata={'author': 'schopenhauer', 'tags': 'ethics'}),
#  Document(page_content='Quote: The difficulty is to try and teach the multitude that something can be true and untrue at the same time., Author:schopenhauer, tags:education;ethics', metadata={'author': 'schopenhauer', 'tags': 'education;ethics'}),
#  Document(page_content='Quote: Life to the great majority is only a constant struggle for mere existence, with the certainty of losing it at last., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: The scenes and events of long ago, and the persons who took part in them, wear a charming aspect to the eye of memory, which sees only the outlines and takes no note of disagreeable details. The present enjoys no such advantage, and so it always seems defective., Author:schopenhauer, tags:history;knowledge', metadata={'author': 'schopenhauer', 'tags': 'history;knowledge'}),
#  Document(page_content='Quote: The effect of music is so very much more powerful and penetrating than is that of the other arts, for these others speak only of the shadow, but music of the essence., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content="Quote: To become indignant at [people's] conduct is as foolish as to be angry with a stone because it rolls into your path. And with many people the wisest thing you can do, is to resolve to make use of those whom you cannot alter., Author:schopenhauer, tags:knowledge;ethics", metadata={'author': 'schopenhauer', 'tags': 'knowledge;ethics'}),
#  Document(page_content='Quote: Necessity is the constant scourge of the lower classes, ennui of the higher ones., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content="Quote: It is most important to allow the brain the full measure of sleep which is required to restore it; for sleep is to a man's whole nature what winding up is to a clock., Author:schopenhauer, tags:ethics;knowledge", metadata={'author': 'schopenhauer', 'tags': 'ethics;knowledge'}),
#  Document(page_content='Quote: It is with trifles, and when he is off guard, that a man best reveals his character., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: A man of business will often deceive you without the slightest scruple, but he will absolutely refuse to commit a theft., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: The ultimate foundation of honor is the conviction that moral character is unalterable: a single bad action implies that future actions of the same kind will, under similar circumstances, also be bad., Author:schopenhauer, tags:ethics', metadata={'author': 'schopenhauer', 'tags': 'ethics'}),
#  Document(page_content="Quote: I've never known any trouble than an hour's reading didn't assuage., Author:schopenhauer, tags:None", metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: What makes people hard-hearted is this, that each man has, or fancies he has, as much as he can bear in his own troubles., Author:schopenhauer, tags:ethics', metadata={'author': 'schopenhauer', 'tags': 'ethics'}),
#  Document(page_content='Quote: A good supply of resignation is of the first importance in providing for the journey of life., Author:schopenhauer, tags:ethics', metadata={'author': 'schopenhauer', 'tags': 'ethics'}),
#  Document(page_content='Quote: To desire immortality for the individual is really the same as wanting to perpetuate an error forever., Author:schopenhauer, tags:ethics', metadata={'author': 'schopenhauer', 'tags': 'ethics'}),
#  Document(page_content='Quote: The cause of laughter is simply the sudden perception of the incongruity between a concept and the real project., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: He who can see truly in the midst of general infatuation is like a man whose watch keeps good time, when all clocks in the town in which he lives are wrong. He alone knows the right time; what use is that to him?, Author:schopenhauer, tags:knowledge;love', metadata={'author': 'schopenhauer', 'tags': 'knowledge;love'}),
#  Document(page_content='Quote: If a person is stupid, we excuse him by saying that he cannot help it; but if we attempted to excuse in precisely the same way the person who is bad, we should be laughed at., Author:schopenhauer, tags:ethics', metadata={'author': 'schopenhauer', 'tags': 'ethics'}),
#  Document(page_content='Quote: My body and my will are one., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: The ordinary method of education is to imprint ideas and opinions, in the strict sense of the word, prejudices, on the mind of the child, before it has had any but a very few particular observations. It is thus that he afterwards comes to view the world and gather experience through the medium of those ready-made ideas, rather than to let his ideas be formed for him out of his own experience of life, as they ought to be., Author:schopenhauer, tags:education', metadata={'author': 'schopenhauer', 'tags': 'education'}),
#  Document(page_content='Quote: One can never read too little of bad, or too much of good books: bad books are intellectual poison; they destroy the mind. In order to read what is good one must make it a condition never to read what is bad; for life is short, and both time and strength limited., Author:schopenhauer, tags:knowledge;ethics;education', metadata={'author': 'schopenhauer', 'tags': 'knowledge;ethics;education'}),
#  Document(page_content="Quote: Many undoubtedly owe their good fortune to the circumstance that they possess a pleasing smile with which they win hearts. Yet these hearts would do better to beware and to learn from Hamlet's tables that one may smile, and smile, and be a villain., Author:schopenhauer, tags:knowledge;education;ethics", metadata={'author': 'schopenhauer', 'tags': 'knowledge;education;ethics'}),
#  Document(page_content='Quote: In the blessings as well as in the ills of life, less depends upon what befalls us than upon the way in which it is met., Author:schopenhauer, tags:knowledge;ethics', metadata={'author': 'schopenhauer', 'tags': 'knowledge;ethics'}),
#  Document(page_content="Quote: It is only a man's own fundamental thoughts that have truth and life in them. For it is these that he really and completely understands. To read the thoughts of others is like taking the remains of someone else's meal, like putting on the discarded clothes of a stranger., Author:schopenhauer, tags:knowledge;ethics;education;history;love", metadata={'author': 'schopenhauer', 'tags': 'knowledge;ethics;education;history;love'}),
#  Document(page_content='Quote: There is no absurdity so palpable but that it may be firmly planted in the human head if you only begin to inculcate it before the age of five, by constantly repeating it with an air of great solemnity., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: Thus also every keen pleasure is an error and an illusion, for no attained wish can give lasting satisfaction., Author:schopenhauer, tags:ethics', metadata={'author': 'schopenhauer', 'tags': 'ethics'}),
#  Document(page_content='Quote: It is a clumsy experiment to make; for it involves the destruction of the very consciousness which puts the question and awaits the answer., Author:schopenhauer, tags:None', metadata={'author': 'schopenhauer', 'tags': None}),
#  Document(page_content='Quote: Nothing in nature is by chance... Something appears to be chance only because of our lack of knowledge., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: When a man is prey to his emotions, he is not his own master., Author:spinoza, tags:ethics', metadata={'author': 'spinoza', 'tags': 'ethics'}),
#  Document(page_content='Quote: The more clearly you understand yourself and your emotions, the more you become a lover of what is., Author:spinoza, tags:love;knowledge;education', metadata={'author': 'spinoza', 'tags': 'love;knowledge;education'}),
#  Document(page_content='Quote: He who seeks equality between unequals seeks an absurdity., Author:spinoza, tags:politics', metadata={'author': 'spinoza', 'tags': 'politics'}),
#  Document(page_content="Quote: Academies that are founded at public expense are instituted not so much to cultivate men's natural abilities as to restrain them., Author:spinoza, tags:education;knowledge", metadata={'author': 'spinoza', 'tags': 'education;knowledge'}),
#  Document(page_content='Quote: Hatred is increased by being reciprocated, and can on the other hand be destroyed by love., Author:spinoza, tags:love', metadata={'author': 'spinoza', 'tags': 'love'}),
#  Document(page_content='Quote: Big fish eat small fish with as much right as they have power., Author:spinoza, tags:politics', metadata={'author': 'spinoza', 'tags': 'politics'}),
#  Document(page_content='Quote: Indulge yourself in pleasures only in so far as they are necessary for the preservation of health., Author:spinoza, tags:ethics', metadata={'author': 'spinoza', 'tags': 'ethics'}),
#  Document(page_content='Quote: [Believers] are but triflers who, when they cannot explain a thing, run back to the will of God; this is, truly, a ridiculous way of expressing ignorance., Author:spinoza, tags:religion', metadata={'author': 'spinoza', 'tags': 'religion'}),
#  Document(page_content='Quote: Let unswerving integrity be your watchword., Author:spinoza, tags:ethics', metadata={'author': 'spinoza', 'tags': 'ethics'}),
#  Document(page_content='Quote: I have made a ceaseless effort not to ridicule, not to bewail, not to scorn human actions, but to understand them., Author:spinoza, tags:knowledge;education;ethics', metadata={'author': 'spinoza', 'tags': 'knowledge;education;ethics'}),
#  Document(page_content="Quote: Sadness diminishes a man's powers, Author:spinoza, tags:None", metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: What everyone wants from life is continuous and genuine happiness., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: Nature is satisfied with little; and if she is, I am also., Author:spinoza, tags:ethics', metadata={'author': 'spinoza', 'tags': 'ethics'}),
#  Document(page_content='Quote: He who loves God cannot endeavor that God should love him in return., Author:spinoza, tags:ethics;religion;love;knowledge', metadata={'author': 'spinoza', 'tags': 'ethics;religion;love;knowledge'}),
#  Document(page_content='Quote: Laws which prescribe what everyone must believe, and forbid men to say or write anything against this or that opinion, are often passed to gratify, or rather to appease the anger of those who cannot abide independent minds., Author:spinoza, tags:politics', metadata={'author': 'spinoza', 'tags': 'politics'}),
#  Document(page_content='Quote: Further conceive, I beg, that a stone, while continuing in motion, should be capable of thinking and knowing, that it is endeavoring, as far as it can, to continue to move. Such a stone, being conscious merely of its own endeavor and not at all indifferent, would believe itself to be completely free, and would think that it continued in motion solely because of its own wish. This is that human freedom, which all boast that they possess, and which consists solely in the fact, that men are conscious of their own desire, but are ignorant of the causes whereby that desire has been determined., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: The supreme mystery of despotism, its prop and stay, is to keep men in a state of deception, and with the specious title of religion to cloak the fear by which they must be held in check, so that they will fight for their servitude as if for salvation., Author:spinoza, tags:religion', metadata={'author': 'spinoza', 'tags': 'religion'}),
#  Document(page_content='Quote: the ultimate aim of government is not to rule, or restrain by fear, nor to exact obedience, but to free every man from fear that he may live in all possible security... In fact the true aim of government is liberty., Author:spinoza, tags:ethics;knowledge', metadata={'author': 'spinoza', 'tags': 'ethics;knowledge'}),
#  Document(page_content='Quote: Everything excellent is as difficult as it is rare., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: Everything in nature is a cause from which there flows some effect., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: Blessed are the weak who think that they are good because they have no claws., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: God is the indwelling and not the transient cause of all things., Author:spinoza, tags:religion', metadata={'author': 'spinoza', 'tags': 'religion'}),
#  Document(page_content='Quote: The greatest secret of monarchic rule...is to keep men deceived and to cloak in the specious name of religion the fear by which they must be checked, so that they will fight for slavery as they would for salvation, and will think it not shameful, but a most honorable achievement, to give their life and blood that one man may have a ground for boasting., Author:spinoza, tags:politics', metadata={'author': 'spinoza', 'tags': 'politics'}),
#  Document(page_content='Quote: All is One (Nature, God), Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: Faith is nothing but obedience and piety., Author:spinoza, tags:religion', metadata={'author': 'spinoza', 'tags': 'religion'}),
#  Document(page_content='Quote: The more intelligible a thing is, the more easily it is retained in the memory, and counterwise, the less intelligible it is, the more easily we forget it., Author:spinoza, tags:knowledge;education;history;ethics', metadata={'author': 'spinoza', 'tags': 'knowledge;education;history;ethics'}),
#  Document(page_content='Quote: Those who wish to seek out the cause of miracles and to understand the things of nature as philosophers, and not to stare at them in astonishment like fools, are soon considered heretical and impious, and proclaimed as such by those whom the mob adores as the interpreters of nature and the gods., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: It is usually the case with most men that their nature is so constituted that they pity those who fare badly and envy those who fare well., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: Fame has also this great drawback, that if we pursue it, we must direct our lives so as to please the fancy of men., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: In the mind there is no absolute or free will., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: None are more taken in by flattery than the proud, who wish to be the first and are not., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: I have tried sedulously not to laugh at the acts of man, nor to lament them, nor to detest them, but to understand them., Author:spinoza, tags:knowledge;education;ethics', metadata={'author': 'spinoza', 'tags': 'knowledge;education;ethics'}),
#  Document(page_content='Quote: Nothing in the universe is contingent, but all things are conditioned to exist and operate in a particular manner by the necessity of the divine nature., Author:spinoza, tags:religion;knowledge;ethics', metadata={'author': 'spinoza', 'tags': 'religion;knowledge;ethics'}),
#  Document(page_content='Quote: If men were born free, they would, so long as they remained free, form no conception of good and evil., Author:spinoza, tags:ethics', metadata={'author': 'spinoza', 'tags': 'ethics'}),
#  Document(page_content='Quote: In so far as the mind sees things in their eternal aspect, it participates in eternity., Author:spinoza, tags:knowledge;ethics', metadata={'author': 'spinoza', 'tags': 'knowledge;ethics'}),
#  Document(page_content='Quote: them., Author:spinoza, tags:knowledge;ethics', metadata={'author': 'spinoza', 'tags': 'knowledge;ethics'}),
#  Document(page_content='Quote: Many errors, of a truth, consist merely in the application of the wrong names of things., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: .... we are a part of nature as a whole, whose order we follow., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: Men will find that they can ... avoid far more easily the perils which beset them on all sides by united action., Author:spinoza, tags:ethics;politics;knowledge', metadata={'author': 'spinoza', 'tags': 'ethics;politics;knowledge'}),
#  Document(page_content='Quote: The order and connection of ideas is the same as the order and connection of things., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: Desire is the essence of a man., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: Love is pleasure accompanied by the idea of an external cause, and hatred pain accompanied by the idea of an external cause., Author:spinoza, tags:love', metadata={'author': 'spinoza', 'tags': 'love'}),
#  Document(page_content='Quote: He that can carp in the most eloquent or acute manner at the weakness of the human mind is held by his fellows as almost divine., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: Emotion, which is suffering, ceases to be suffering as soon as we form a clear and precise picture of it., Author:spinoza, tags:None', metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: Better that right counsels be known to enemies than that the evil secrets of tyrants should be concealed from the citizens. They who can treat secretly of the affairs of a nation have it absolutely under their authority; and as they plot against the enemy in time of war, so do they against the citizens in time of peace., Author:spinoza, tags:knowledge;ethics;politics', metadata={'author': 'spinoza', 'tags': 'knowledge;ethics;politics'}),
#  Document(page_content='Quote: A man is as much affected pleasurably or painfully by the image of a thing past or future as by the image of a thing present., Author:spinoza, tags:history', metadata={'author': 'spinoza', 'tags': 'history'}),
#  Document(page_content='Quote: Love or hatred towards a thing, which we conceive to be free, must, other things being similar, be greater than if it were felt towards a thing acting by necessity., Author:spinoza, tags:ethics', metadata={'author': 'spinoza', 'tags': 'ethics'}),
#  Document(page_content='Quote: Only that thing is free which exists by the necessities of its own nature, and is determined in its actions by itself alone., Author:spinoza, tags:ethics', metadata={'author': 'spinoza', 'tags': 'ethics'}),
#  Document(page_content="Quote: Men would never be superstitious, if they could govern all their circumstances by set rules, or if they were always favoured by fortune: but being frequently driven into straits where rules are useless, and being often kept fluctuating pitiably between hope and fear by the uncertainty of fortune's greedily coveted favours, they are consequently for the most part, very prone to credulity., Author:spinoza, tags:None", metadata={'author': 'spinoza', 'tags': None}),
#  Document(page_content='Quote: We learn from history that we do not learn from history, Author:hegel, tags:history;knowledge', metadata={'author': 'hegel', 'tags': 'history;knowledge'}),
#  Document(page_content='Quote: To be independent of public opinion is the first formal condition of achieving anything great., Author:hegel, tags:ethics;education', metadata={'author': 'hegel', 'tags': 'ethics;education'}),
#  Document(page_content='Quote: To be aware of limitations is already to be beyond them., Author:hegel, tags:ethics', metadata={'author': 'hegel', 'tags': 'ethics'}),
#  Document(page_content='Quote: What history teaches us is that neither nations nor governments ever learn anything from it., Author:hegel, tags:history', metadata={'author': 'hegel', 'tags': 'history'}),
#  Document(page_content='Quote: The valor that struggles is better than the weakness that endures., Author:hegel, tags:ethics;education', metadata={'author': 'hegel', 'tags': 'ethics;education'}),
#  Document(page_content='Quote: The more certain our knowledge the less we know., Author:hegel, tags:knowledge;education;ethics;history', metadata={'author': 'hegel', 'tags': 'knowledge;education;ethics;history'}),
#  Document(page_content='Quote: In a true tragedy, both parties must be right., Author:hegel, tags:politics', metadata={'author': 'hegel', 'tags': 'politics'}),
#  Document(page_content='Quote: Before the end of Time will be the end of History. Before the end of History will be the end of Art., Author:hegel, tags:history', metadata={'author': 'hegel', 'tags': 'history'}),
#  Document(page_content='Quote: Poverty in itself does not make men into a rabble; a rabble is created only when there is joined to poverty a disposition of mind, an inner indignation against the rich, against society, against the government., Author:hegel, tags:ethics;knowledge', metadata={'author': 'hegel', 'tags': 'ethics;knowledge'}),
#  Document(page_content='Quote: The learner always begins by finding fault, but the scholar sees the positive merit in everything., Author:hegel, tags:education;knowledge;history;ethics', metadata={'author': 'hegel', 'tags': 'education;knowledge;history;ethics'}),
#  Document(page_content='Quote: An idea is always a generalization, and generalization is a property of thinking. To generalize means to think., Author:hegel, tags:None', metadata={'author': 'hegel', 'tags': None}),
#  Document(page_content='Quote: Genuine tragedy is a case not of right against wrong but of right against right - two equally justified ethical principles embodied in people of unchangeable will., Author:hegel, tags:None', metadata={'author': 'hegel', 'tags': None}),
#  Document(page_content="Quote: America is therefore the land of the future, where, in the ages that lie before us, the burden of the World's History shall reveal itself., Author:hegel, tags:knowledge;history", metadata={'author': 'hegel', 'tags': 'knowledge;history'}),
#  Document(page_content='Quote: The history of the world is none other than the progress of the , consciousness of freedom., Author:hegel, tags:history', metadata={'author': 'hegel', 'tags': 'history'}),
#  Document(page_content='Quote: Beauty is merely the Spiritual making itself known sensuously., Author:hegel, tags:None', metadata={'author': 'hegel', 'tags': None}),
#  Document(page_content='Quote: All education is the art of making men ethical (sittlich), of transforming the old Adam into the new Adam., Author:hegel, tags:education;ethics;knowledge', metadata={'author': 'hegel', 'tags': 'education;ethics;knowledge'}),
#  Document(page_content='Quote: Impatience asks for the impossible, wants to reach the goal without the means of getting there. The length of the journey has to be borne with, for every moment is necessary., Author:hegel, tags:ethics', metadata={'author': 'hegel', 'tags': 'ethics'}),
#  Document(page_content='Quote: It is solely by risking life that freedom is obtained; . . . the individual who has not staked his or her life may, no doubt, be recognized as a Person; but he or she has not attained the truth of this recognition as an independent self-consciousness., Author:hegel, tags:ethics', metadata={'author': 'hegel', 'tags': 'ethics'}),
#  Document(page_content='Quote: To make abstractions hold in reality is to destroy reality., Author:hegel, tags:None', metadata={'author': 'hegel', 'tags': None}),
#  Document(page_content='Quote: Philosophy is by its nature something esoteric, neither made for the mob nor capable of being prepared for the mob., Author:hegel, tags:None', metadata={'author': 'hegel', 'tags': None}),
#  Document(page_content='Quote: We learn from history that man can never learn anything from history., Author:hegel, tags:history', metadata={'author': 'hegel', 'tags': 'history'}),
#  Document(page_content='Quote: Freedom is the fundamental character of the will, as weight is of matter... That which is free is the will. Will without freedom is an empty word., Author:hegel, tags:ethics', metadata={'author': 'hegel', 'tags': 'ethics'}),
#  Document(page_content='Quote: The people are that part of the state that does not know what it wants., Author:hegel, tags:politics', metadata={'author': 'hegel', 'tags': 'politics'}),
#  Document(page_content='Quote: We do not need to be shoemakers to know if our shoes fit, and just as little have we any need to be professionals to acquire knowledge of matters of universal interest., Author:hegel, tags:knowledge', metadata={'author': 'hegel', 'tags': 'knowledge'}),
#  Document(page_content='Quote: World history is a court of judgment., Author:hegel, tags:history', metadata={'author': 'hegel', 'tags': 'history'}),
#  Document(page_content='Quote: The length of the journey has to be borne with, for every moment is necessary., Author:hegel, tags:ethics', metadata={'author': 'hegel', 'tags': 'ethics'}),
#  Document(page_content='Quote: The True is the whole. But the whole is nothing other than the essence consummating itself through its development. Of the Absolute it must be said that it is essentially a result, that only in the end is it what it truly is; and that precisely in this consists its nature, viz. to be actual, subject, the spontaneous becoming of itself., Author:hegel, tags:None', metadata={'author': 'hegel', 'tags': None}),
#  Document(page_content='Quote: Regarding History as the slaughter-bench at which the happiness of peoples, the wisdom of States, and the virtue of individuals have been victimized--the question involuntarily arises--to what principle, to what final aim these enormous sacrifices have been offered., Author:hegel, tags:history', metadata={'author': 'hegel', 'tags': 'history'}),
#  Document(page_content='Quote: The proofs of the existence of God are to such an extent fallen into discredit that they pass for something antiquated, belonging to days gone by., Author:hegel, tags:history;religion', metadata={'author': 'hegel', 'tags': 'history;religion'}),
#  Document(page_content="Quote: The bud disappears when the blossom breaks through, and we might say that the former is refuted by the latter; in the same way when the fruit comes, the blossom may be explained to be a false form of the plant's existence, for the fruit appears as its true nature in place of the blossom., Author:hegel, tags:None", metadata={'author': 'hegel', 'tags': None}),
#  Document(page_content='Quote: The true courage of civilized nations is readiness for sacrifice in the service of the state, so that the individual counts as only one amongst many. The important thing here is not personal mettle but aligning oneself with the universal., Author:hegel, tags:ethics;politics;knowledge', metadata={'author': 'hegel', 'tags': 'ethics;politics;knowledge'}),
#  Document(page_content='Quote: The heart-throb for the welfare of humanity therefore passes into the ravings of an insane self-conceit, into the fury of consciousness to preserve itself from destruction; and it does this by expelling from itself the perversion which it is itself, and by striving to look on it and express it as something else., Author:hegel, tags:None', metadata={'author': 'hegel', 'tags': None}),
#  Document(page_content='Quote: The Catholics had been in the position of oppressors, and the Protestants of the oppressed, Author:hegel, tags:religion;politics;history;ethics', metadata={'author': 'hegel', 'tags': 'religion;politics;history;ethics'}),
#  Document(page_content='Quote: To him who looks upon the world rationally, the world in its turn presents a rational aspect. The relation is mutual., Author:hegel, tags:knowledge;ethics', metadata={'author': 'hegel', 'tags': 'knowledge;ethics'}),
#  Document(page_content='Quote: Propounding peace and love without practical or institutional engagement is delusion, not virtue., Author:hegel, tags:None', metadata={'author': 'hegel', 'tags': None}),
#  Document(page_content='Quote: It strikes everyone in beginning to form an acquaintance with the treasures of Indian literature that a land so rich in intellectual products and those of the profoundest order of thought., Author:hegel, tags:knowledge', metadata={'author': 'hegel', 'tags': 'knowledge'}),
#  Document(page_content='Quote: The people will learn to feel the dignity of man. They will not merely demand their rights, which have been trampled in the dust, but themselves will take them - make them their own., Author:hegel, tags:knowledge;ethics;education;politics', metadata={'author': 'hegel', 'tags': 'knowledge;ethics;education;politics'}),
# ...
#  Document(page_content='Quote: Pleasure is the bait of sin, Author:plato, tags:None', metadata={'author': 'plato', 'tags': None}),
#  Document(page_content='Quote: A good decision is based on knowledge, and not on numbers., Author:plato, tags:knowledge;education', metadata={'author': 'plato', 'tags': 'knowledge;education'}),
#  Document(page_content='Quote: When man is not properly trained, he is the most savage animal on the face of the globe., Author:plato, tags:ethics', metadata={'author': 'plato', 'tags': 'ethics'}),
#  Document(page_content='Quote: Happiness springs from doing good and helping others., Author:plato, tags:ethics', metadata={'author': 'plato', 'tags': 'ethics'}),
#  Document(page_content='Quote: One of the penalties for refusing to participate in politics is that you end up being governed by your inferiors., Author:plato, tags:politics', metadata={'author': 'plato', 'tags': 'politics'}),
#  Document(page_content='Quote: The blame is his who chooses: God is blameless., Author:plato, tags:religion;ethics;knowledge', metadata={'author': 'plato', 'tags': 'religion;ethics;knowledge'}),
#  Document(page_content='Quote: Harmony sinks deep into the recesses of the soul and takes its strongest hold there, bringing grace also to the body & mind as well. Music is a moral law. It gives a soul to the universe, wings to the mind, flight to the imagination, a charm to sadness, and life to everything. It is the essence of order., Author:plato, tags:None', metadata={'author': 'plato', 'tags': None}),
#  Document(page_content='Quote: Do not expect justice where might is right., Author:plato, tags:None', metadata={'author': 'plato', 'tags': None}),
#  Document(page_content='Quote: When you feel grateful, you become great, and eventually attract great things., Author:plato, tags:ethics;knowledge', metadata={'author': 'plato', 'tags': 'ethics;knowledge'}),
#  Document(page_content='Quote: If we are to have any hope for the future, those who have lanterns must pass them on to others., Author:plato, tags:ethics', metadata={'author': 'plato', 'tags': 'ethics'}),
#  Document(page_content='Quote: We see many instances of cities going down like sinking ships to their destruction. There have been such wrecks in the past and there surely will be others in the future, caused by the wickedness of captains and crews alike. For these are guilty men, whose sin is supreme ignorance of what matters most., Author:plato, tags:None', metadata={'author': 'plato', 'tags': None}),
#  Document(page_content='Quote: Mankind will never see an end of trouble until lovers of wisdom come to hold political power, or the holders of power become lovers of wisdom, Author:plato, tags:politics;knowledge', metadata={'author': 'plato', 'tags': 'politics;knowledge'}),
#  Document(page_content='Quote: Those who are too smart to engage in politics are punished by being governed by those who are dumber., Author:plato, tags:politics;knowledge', metadata={'author': 'plato', 'tags': 'politics;knowledge'}),
#  Document(page_content='Quote: A dog has the soul of a philosopher., Author:plato, tags:ethics', metadata={'author': 'plato', 'tags': 'ethics'}),
#  Document(page_content='Quote: Thinking is the soul talking to itself., Author:plato, tags:None', metadata={'author': 'plato', 'tags': None}),
#  Document(page_content='Quote: midwife to the awakening of the Soul in another person., Author:plato, tags:love;knowledge', metadata={'author': 'plato', 'tags': 'love;knowledge'}),
#  Document(page_content='Quote: All wars are fought for the sake of getting money., Author:plato, tags:None', metadata={'author': 'plato', 'tags': None}),
#  Document(page_content='Quote: Rules for Happiness: something to do, someone to love, something to hope for., Author:kant, tags:love', metadata={'author': 'kant', 'tags': 'love'}),
#  Document(page_content='Quote: Do the right thing because it is right., Author:kant, tags:ethics', metadata={'author': 'kant', 'tags': 'ethics'}),
#  Document(page_content='Quote: The only thing permanent is change., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: Give a man everything he wants and at that moment everything is not everything, Author:kant, tags:ethics', metadata={'author': 'kant', 'tags': 'ethics'}),
#  Document(page_content='Quote: Great minds think for themselves., Author:kant, tags:knowledge', metadata={'author': 'kant', 'tags': 'knowledge'}),
#  Document(page_content='Quote: Perpetual Peace is only found in the graveyard., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: A single line in the Bible has consoled me more than all the books I ever read besides., Author:kant, tags:religion;love', metadata={'author': 'kant', 'tags': 'religion;love'}),
#  Document(page_content='Quote: All our knowledge begins with the senses, proceeds then to the understanding, and ends with reason. There is nothing higher than reason., Author:kant, tags:knowledge;history;education', metadata={'author': 'kant', 'tags': 'knowledge;history;education'}),
#  Document(page_content='Quote: If justice perishes, human life on Earth has lost its meaning., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: Morality is not properly the doctrine of how we may make ourselves happy, but how we may make ourselves worthy of happiness., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: Out of the crooked timber of humanity, no straight thing was ever made., Author:kant, tags:ethics', metadata={'author': 'kant', 'tags': 'ethics'}),
#  Document(page_content='Quote: Thoughts without content are empty, intuitions without concepts are blind., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content="Quote: Immaturity is the incapacity to use one's intelligence without the guidance of another., Author:kant, tags:None", metadata={'author': 'kant', 'tags': None}),
#  Document(page_content="Quote: The nice thing about living in a small town is that when you don't know what you're doing, someone else does., Author:kant, tags:None", metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: Two things strike me dumb: the infinite starry heavens, and the sense of right and wrong in man., Author:kant, tags:ethics', metadata={'author': 'kant', 'tags': 'ethics'}),
#  Document(page_content='Quote: Reason can never prove the existence of God., Author:kant, tags:religion', metadata={'author': 'kant', 'tags': 'religion'}),
#  Document(page_content='Quote: All the interests of my reason, speculative as well as practical, combine in the three following questions: 1. What can I know? 2. What ought I to do? 3. What may I hope?, Author:kant, tags:knowledge', metadata={'author': 'kant', 'tags': 'knowledge'}),
#  Document(page_content='Quote: By a lie, a man... annihilates his dignity as a man., Author:kant, tags:politics;ethics', metadata={'author': 'kant', 'tags': 'politics;ethics'}),
#  Document(page_content='Quote: Religion is too important a matter to its devotees to be a subject of ridicule. If they indulge in absurdities, they are to be pitied rather than ridiculed., Author:kant, tags:religion', metadata={'author': 'kant', 'tags': 'religion'}),
#  Document(page_content='Quote: Enthusiasm is always connected with the senses, whatever be the object that excites it. The true strength of virtue is serenity of mind, combined with a deliberate and steadfast determination to execute her laws. That is the healthful condition of the moral life; on the other hand, enthusiasm, even when excited by representations of goodness, is a brilliant but feverish glow which leaves only exhaustion and languor behind., Author:kant, tags:ethics', metadata={'author': 'kant', 'tags': 'ethics'}),
#  Document(page_content="Quote: Men will not understand ... that when they fulfil their duties to men, they fulfil thereby God's commandments; that they are consequently always in the service of God, as long as their actions are moral, and that it is absolutely impossible to serve God otherwise., Author:kant, tags:ethics;religion", metadata={'author': 'kant', 'tags': 'ethics;religion'}),
#  Document(page_content='Quote: [A ruler is merely] the trustee of the rights of other men and he must always stand in dread of having in some way violated these rights., Author:kant, tags:ethics', metadata={'author': 'kant', 'tags': 'ethics'}),
#  Document(page_content='Quote: The death of dogma is the birth of morality., Author:kant, tags:ethics', metadata={'author': 'kant', 'tags': 'ethics'}),
#  Document(page_content='Quote: Freedom is that faculty that enlarges the usefulness of all other faculties., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: The sum total of all possible knowledge of God is not possible for a human being, not even through a true revelation. But it is one of the worthiest inquiries to see how far our reason can go in the knowledge of God., Author:kant, tags:knowledge', metadata={'author': 'kant', 'tags': 'knowledge'}),
#  Document(page_content='Quote: Philosophy stands in need of a science which shall determine the possibility, principles, and extent of human knowledge  priori., Author:kant, tags:knowledge', metadata={'author': 'kant', 'tags': 'knowledge'}),
#  Document(page_content="Quote: Thrift is care and scruple in the spending of one's means. It is not a virtue and it requires neither skill nor talent., Author:kant, tags:ethics", metadata={'author': 'kant', 'tags': 'ethics'}),
#  Document(page_content='Quote: If a man is often the subject of conversation he soon becomes the subject of criticism., Author:kant, tags:ethics', metadata={'author': 'kant', 'tags': 'ethics'}),
#  Document(page_content="Quote: Enlightenment is man's emergence from his self-incurred immaturity., Author:kant, tags:education;knowledge", metadata={'author': 'kant', 'tags': 'education;knowledge'}),
#  Document(page_content='Quote: Give me matter, and I will construct a world out of it!, Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content="Quote: Even a man's exact imitation of the song of the nightingale displeases us when we discover that it is a mimicry, and not the nightingale., Author:kant, tags:ethics;knowledge", metadata={'author': 'kant', 'tags': 'ethics;knowledge'}),
#  Document(page_content='Quote: [R]eason is... given to us as a practical faculty, that is, as one that influences the will., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: The business of philosophy is not to give rules, but to analyze the private judgments of common reason., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: Moral Teleology supplies the deficiency in physical Teleology , and first establishes a Theology ; because the latter, if it did not borrow from the former without being observed, but were to proceed consistently, could only found a Demonology , which is incapable of any definite concept., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: There is nothing higher than reason., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: Time is not an empirical concept. For neither co-existence nor succession would be perceived by us, if the representation of time did not exist as a foundation a priori., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: Have patience awhile; slanders are not long-lived. Truth is the child of time; erelong she shall appear to vindicate thee., Author:kant, tags:knowledge;ethics;history;education', metadata={'author': 'kant', 'tags': 'knowledge;ethics;history;education'}),
#  Document(page_content='Quote: But only he who, himself enlightened, is not afraid of shadows., Author:kant, tags:knowledge;education;ethics', metadata={'author': 'kant', 'tags': 'knowledge;education;ethics'}),
#  Document(page_content='Quote: There is needed, no doubt, a body of servants (ministerium) of the invisible church, but not officials (officiales), in other words, teachers but not dignitaries, because in the rational religion of every individual there does not yet exist a church as a universal union (omnitudo collectiva)., Author:kant, tags:religion;education;knowledge', metadata={'author': 'kant', 'tags': 'religion;education;knowledge'}),
#  Document(page_content='Quote: Reason must approach nature in order to be taught by it. It must not, however, do so in the character of a pupil who listens to everything that the teacher chooses to say, but of an appointed judge who compels the witness to answer questions which he has himself formulated., Author:kant, tags:education;knowledge', metadata={'author': 'kant', 'tags': 'education;knowledge'}),
#  Document(page_content='Quote: But although all our knowledge begins with experience, it does not follow that it arises from experience., Author:kant, tags:knowledge;ethics;education', metadata={'author': 'kant', 'tags': 'knowledge;ethics;education'}),
#  Document(page_content='Quote: Enlightenment is the liberation of man from his self-caused state of minority... Supere aude! Dare to use your own understanding!is thus the motto of the Enlightenment., Author:kant, tags:knowledge', metadata={'author': 'kant', 'tags': 'knowledge'}),
#  Document(page_content='Quote: The history of the human race, viewed as a whole, may be regarded as the realization of a hidden plan of nature to bring about a political constitution, internally, and for this purpose, also externally perfect, as the only state in which all the capacities implanted by her in mankind can be fully developed., Author:kant, tags:history;politics', metadata={'author': 'kant', 'tags': 'history;politics'}),
#  Document(page_content='Quote: Standing armies shall in time be totally abolished., Author:kant, tags:history', metadata={'author': 'kant', 'tags': 'history'}),
#  Document(page_content='Quote: Criticism alone can sever the root of materialism, fatalism, atheism, free-thinking, fanaticism, and superstition, which can be injurious universally; as well as of idealism and skepticism, which are dangerous chiefly to the Schools, and hardly allow of being handed on to the public., Author:kant, tags:education', metadata={'author': 'kant', 'tags': 'education'}),
#  Document(page_content='Quote: Everything in nature acts in conformity with law., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: I freely admit that the remembrance of David Hume was the very thing that many years ago first interrupted my dogmatic slumber and gave a completely different direction to my researches in the field of speculative philosophy., Author:kant, tags:knowledge;history', metadata={'author': 'kant', 'tags': 'knowledge;history'}),
#  Document(page_content='Quote: All trades, arts, and handiworks have gained by division of labor... Where the different kinds of work are not distinguished and divided, where everyone is a jack-of-all-trades, there manufactures remain still in the greatest barbarism., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: Innocence is indeed a glorious thing; but, unfortunately, it does not keep very well and is easily led astray., Author:kant, tags:None', metadata={'author': 'kant', 'tags': None}),
#  Document(page_content='Quote: The schematicism by which our understanding deals with the phenomenal world ... is a skill so deeply hidden in the human soul that we shall hardly guess the secret trick that Nature here employs., Author:kant, tags:knowledge', metadata={'author': 'kant', 'tags': 'knowledge'})]

# %%
retriever = vstore.as_retriever()
docs = retriever.get_relevant_documents("get me a quote of plato")
print(docs)
# Out:
# [Document(page_content='Quote: Do not expect justice where might is right., Author:plato, tags:None', metadata={'author': 'plato', 'tags': None}), Document(page_content='Quote: Thinking is the soul talking to itself., Author:plato, tags:None', metadata={'author': 'plato', 'tags': None}), Document(page_content='Quote: Ignorance is the root cause of all difficulties., Author:plato, tags:None', metadata={'author': 'plato', 'tags': None}), Document(page_content='Quote: Plato is my friend, but truth is a better friend., Author:aristotle, tags:None', metadata={'author': 'aristotle', 'tags': None})]

# %%
docs
# Out:
# [Document(page_content='Do the right thing because it is right.', metadata={'author': 'kant', 'tags': 'ethics'}),
#  Document(page_content='Character is that which reveals moral purpose, exposing the class of things a man chooses and avoids.', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Philosophy begins with wonder.', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='A moral system valid for all is basically immoral.', metadata={'author': 'nietzsche', 'tags': None})]

# %%
from langchain.chains.query_constructor.base import AttributeInfo
from langchain.retrievers.self_query.base import SelfQueryRetriever
metadata_field_info = [
    AttributeInfo(
        name="author",
        description="The Author of the Quote",
        type="string",
    ),
    AttributeInfo(
        name="tags",
        description="Further information about the quote, like a tag or category",
        type="string or list[string]",
    ),
]
document_content_description = "The text of the quote from the philosopher."
retriever2 = SelfQueryRetriever.from_llm(
    llm, vstore, document_content_description, metadata_field_info, verbose=True,search_kwargs={'k': 2}
)

# %%
docs = retriever2.get_relevant_documents("Get me a about ethics from author aristotle")
print(docs)
# Out:
# [Document(page_content='You are what you repeatedly do', metadata={'author': 'aristotle', 'tags': None}), Document(page_content='Philosophy begins with wonder.', metadata={'author': 'aristotle', 'tags': None})]

# %%
from pydantic.v1 import BaseModel, Field

from typing import List
from langchain_core.output_parsers import BaseOutputParser
from langchain.chains import LLMChain
from langchain.output_parsers import PydanticOutputParser
from langchain_core.prompts import PromptTemplate
from pydantic import BaseModel, Field
from langchain.retrievers.multi_query import MultiQueryRetriever

class LineListOutputParser(BaseOutputParser[List[str]]):
    """Output parser for a list of lines."""

    def parse(self, text: str):
        """
        Parses the given text and returns a LineList object.

        Args:
            text (str): The text to be parsed.

        Returns:
            LineList: The parsed LineList object.
        """
        print(f'parsing text: {text} \n')
        lines = text.strip().split("\n")
        lines = [
            line for line in lines if line.strip()
            and "alternative" not in line and "original question" not in line
        ]
        return lines


output_parser = LineListOutputParser()

QUERY_PROMPT = PromptTemplate(
    input_variables=["question"],
    template="""You are an AI language model assistant. Your task is to generate two 
    different versions of the given user question to retrieve relevant quotes from a vector 
    database. By generating multiple perspectives on the user question, your goal is to help
    the user overcome some of the limitations of the distance-based similarity search. Do not change the meaning of the question, do not change the authors name or the tag
    Provide these alternative questions separated by newlines. also mention the original question. And have question vartion by adding the author name as author: name of author in lower case also add tag: tag name in lower case.
    Original question: {question}""",
)

# Chain
llm_chain = LLMChain(llm=llm, prompt=QUERY_PROMPT, output_parser=output_parser)

# Other inputs
# question =

# %%
# Run
retriever = MultiQueryRetriever(
    retriever=retriever2, llm_chain=llm_chain, parser_key="lines", include_original=True)  # "lines" is the key (attribute name) of the parsed output
unique_docs = retriever.get_relevant_documents(
    query="What did Aristotle say about ethics?")
# Out:
# parsing text: Original question: What did Aristotle say about ethics?
#
# Alternative question 1: What are Aristotle's views on the nature of ethics? author: aristotle tag: ethics
# Alternative question 2: How did Aristotle define the concept of ethical behavior? author: aristotle tag: ethics
# ---------------------------------------------------------------------------
# UnexpectedCharacters                      Traceback (most recent call last)
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/lark/lexer.py:665, in ContextualLexer.lex(self, lexer_state, parser_state)
#     664         lexer = self.lexers[parser_state.position]
# --> 665         yield lexer.next_token(lexer_state, parser_state)
#     666 except EOFError:
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/lark/lexer.py:598, in BasicLexer.next_token(self, lex_state, parser_state)
#     597         allowed = {"<END-OF-FILE>"}
# --> 598     raise UnexpectedCharacters(lex_state.text, line_ctr.char_pos, line_ctr.line, line_ctr.column,
#     599                                allowed=allowed, token_history=lex_state.last_token and [lex_state.last_token],
#     600                                state=parser_state, terminals_by_name=self.terminals_by_name)
#     602 value, type_ = res
#
# UnexpectedCharacters: No terminal matches 'a' in the current parser context, at line 1 col 27
#
# eq("author", "Aristotle") and in("tags", "ethics")
#                           ^
# Expected one of:
# 	* RPAR
# 	* COMMA
# 	* RSQB
#
# Previous tokens: Token('RPAR', ')')
#
#
# During handling of the above exception, another exception occurred:
#
# UnexpectedToken                           Traceback (most recent call last)
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain/chains/query_constructor/base.py:56, in StructuredQueryOutputParser.parse(self, text)
#      55 else:
# ---> 56     parsed["filter"] = self.ast_parse(parsed["filter"])
#      57 if not parsed.get("limit"):
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/lark/lark.py:658, in Lark.parse(self, text, start, on_error)
#     641 """Parse the given text, according to the options provided.
#     642
#     643 Parameters:
#    (...)
#     656
#     657 """
# --> 658 return self.parser.parse(text, start=start, on_error=on_error)
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/lark/parser_frontends.py:104, in ParsingFrontend.parse(self, text, start, on_error)
#     103 stream = self._make_lexer_thread(text)
# --> 104 return self.parser.parse(stream, chosen_start, **kw)
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/lark/parsers/lalr_parser.py:42, in LALR_Parser.parse(self, lexer, start, on_error)
#      41 try:
# ---> 42     return self.parser.parse(lexer, start)
#      43 except UnexpectedInput as e:
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/lark/parsers/lalr_parser.py:88, in _Parser.parse(self, lexer, start, value_stack, state_stack, start_interactive)
#      87     return InteractiveParser(self, parser_state, parser_state.lexer)
# ---> 88 return self.parse_from_state(parser_state)
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/lark/parsers/lalr_parser.py:111, in _Parser.parse_from_state(self, state, last_token)
#     110         pass
# --> 111     raise e
#     112 except Exception as e:
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/lark/parsers/lalr_parser.py:100, in _Parser.parse_from_state(self, state, last_token)
#      99 token = last_token
# --> 100 for token in state.lexer.lex(state):
#     101     assert token is not None
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/lark/lexer.py:674, in ContextualLexer.lex(self, lexer_state, parser_state)
#     673     token = self.root_lexer.next_token(lexer_state, parser_state)
# --> 674     raise UnexpectedToken(token, e.allowed, state=parser_state, token_history=[last_token], terminals_by_name=self.root_lexer.terminals_by_name)
#     675 except UnexpectedCharacters:
#
# UnexpectedToken: Unexpected token Token('CNAME', 'and') at line 1, column 27.
# Expected one of:
# 	* $END
# Previous tokens: [Token('RPAR', ')')]
#
#
# During handling of the above exception, another exception occurred:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[47], line 4
#       1 # Run
#       2 retriever = MultiQueryRetriever(
#       3     retriever=retriever2, llm_chain=llm_chain, parser_key="lines", include_original=True)  # "lines" is the key (attribute name) of the parsed output
# ----> 4 unique_docs = retriever.get_relevant_documents(
#       5     query="What did Aristotle say about ethics?"
#       6 )
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain_core/retrievers.py:244, in BaseRetriever.get_relevant_documents(self, query, callbacks, tags, metadata, run_name, **kwargs)
#     242 except Exception as e:
#     243     run_manager.on_retriever_error(e)
# --> 244     raise e
#     245 else:
#     246     run_manager.on_retriever_end(
#     247         result,
#     248     )
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain_core/retrievers.py:237, in BaseRetriever.get_relevant_documents(self, query, callbacks, tags, metadata, run_name, **kwargs)
#     235 _kwargs = kwargs if self._expects_other_args else {}
#     236 if self._new_arg_supported:
# --> 237     result = self._get_relevant_documents(
#     238         query, run_manager=run_manager, **_kwargs
#     239     )
#     240 else:
#     241     result = self._get_relevant_documents(query, **_kwargs)
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain/retrievers/multi_query.py:164, in MultiQueryRetriever._get_relevant_documents(self, query, run_manager)
#     162 if self.include_original:
#     163     queries.append(query)
# --> 164 documents = self.retrieve_documents(queries, run_manager)
#     165 return self.unique_union(documents)
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain/retrievers/multi_query.py:199, in MultiQueryRetriever.retrieve_documents(self, queries, run_manager)
#     197 documents = []
#     198 for query in queries:
# --> 199     docs = self.retriever.get_relevant_documents(
#     200         query, callbacks=run_manager.get_child()
#     201     )
#     202     documents.extend(docs)
#     203 return documents
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain_core/retrievers.py:244, in BaseRetriever.get_relevant_documents(self, query, callbacks, tags, metadata, run_name, **kwargs)
#     242 except Exception as e:
#     243     run_manager.on_retriever_error(e)
# --> 244     raise e
#     245 else:
#     246     run_manager.on_retriever_end(
#     247         result,
#     248     )
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain_core/retrievers.py:237, in BaseRetriever.get_relevant_documents(self, query, callbacks, tags, metadata, run_name, **kwargs)
#     235 _kwargs = kwargs if self._expects_other_args else {}
#     236 if self._new_arg_supported:
# --> 237     result = self._get_relevant_documents(
#     238         query, run_manager=run_manager, **_kwargs
#     239     )
#     240 else:
#     241     result = self._get_relevant_documents(query, **_kwargs)
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain/retrievers/self_query/base.py:184, in SelfQueryRetriever._get_relevant_documents(self, query, run_manager)
#     173 def _get_relevant_documents(
#     174     self, query: str, *, run_manager: CallbackManagerForRetrieverRun
#     175 ) -> List[Document]:
#     176     """Get documents relevant for a query.
#     177
#     178     Args:
#    (...)
#     182         List of relevant documents
#     183     """
# --> 184     structured_query = self.query_constructor.invoke(
#     185         {"query": query}, config={"callbacks": run_manager.get_child()}
#     186     )
#     187     if self.verbose:
#     188         logger.info(f"Generated Query: {structured_query}")
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain_core/runnables/base.py:4090, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    4084 def invoke(
#    4085     self,
#    4086     input: Input,
#    4087     config: Optional[RunnableConfig] = None,
#    4088     **kwargs: Optional[Any],
#    4089 ) -> Output:
# -> 4090     return self.bound.invoke(
#    4091         input,
#    4092         self._merge_configs(config),
#    4093         **{**self.kwargs, **kwargs},
#    4094     )
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain_core/runnables/base.py:2089, in RunnableSequence.invoke(self, input, config)
#    2087 try:
#    2088     for i, step in enumerate(self.steps):
# -> 2089         input = step.invoke(
#    2090             input,
#    2091             # mark each step as a child run
#    2092             patch_config(
#    2093                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2094             ),
#    2095         )
#    2096 # finish the root run
#    2097 except BaseException as e:
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain_core/output_parsers/base.py:178, in BaseOutputParser.invoke(self, input, config)
#     169     return self._call_with_config(
#     170         lambda inner_input: self.parse_result(
#     171             [ChatGeneration(message=inner_input)]
#    (...)
#     175         run_type="parser",
#     176     )
#     177 else:
# --> 178     return self._call_with_config(
#     179         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180         input,
#     181         config,
#     182         run_type="parser",
#     183     )
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain_core/runnables/base.py:1276, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1272     context = copy_context()
#    1273     context.run(var_child_runnable_config.set, child_config)
#    1274     output = cast(
#    1275         Output,
# -> 1276         context.run(
#    1277             call_func_with_variable_args,  # type: ignore[arg-type]
#    1278             func,  # type: ignore[arg-type]
#    1279             input,  # type: ignore[arg-type]
#    1280             config,
#    1281             run_manager,
#    1282             **kwargs,
#    1283         ),
#    1284     )
#    1285 except BaseException as e:
#    1286     run_manager.on_chain_error(e)
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain_core/runnables/config.py:326, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     324 if run_manager is not None and accepts_run_manager(func):
#     325     kwargs["run_manager"] = run_manager
# --> 326 return func(input, **kwargs)
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain_core/output_parsers/base.py:179, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     169     return self._call_with_config(
#     170         lambda inner_input: self.parse_result(
#     171             [ChatGeneration(message=inner_input)]
#    (...)
#     175         run_type="parser",
#     176     )
#     177 else:
#     178     return self._call_with_config(
# --> 179         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180         input,
#     181         config,
#     182         run_type="parser",
#     183     )
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain_core/output_parsers/base.py:221, in BaseOutputParser.parse_result(self, result, partial)
#     208 def parse_result(self, result: List[Generation], *, partial: bool = False) -> T:
#     209     """Parse a list of candidate model Generations into a specific format.
#     210
#     211     The return value is parsed from only the first Generation in the result, which
#    (...)
#     219         Structured output.
#     220     """
# --> 221     return self.parse(result[0].text)
#
# File ~/Documents/GitHub/Datastax/RAGStackDemo/.venv/lib/python3.11/site-packages/langchain/chains/query_constructor/base.py:63, in StructuredQueryOutputParser.parse(self, text)
#      59     return StructuredQuery(
#      60         **{k: v for k, v in parsed.items() if k in allowed_keys}
#      61     )
#      62 except Exception as e:
# ---> 63     raise OutputParserException(
#      64         f"Parsing text\n{text}\n raised following error:\n{e}"
#      65     )
#
# OutputParserException: Parsing text
# ```json
# {
#     "query": "nature of ethics",
#     "filter": "eq(\"author\", \"Aristotle\") and in(\"tags\", \"ethics\")"
# }
# ```
#  raised following error:
# Unexpected token Token('CNAME', 'and') at line 1, column 27.
# Expected one of:
# 	* $END
# Previous tokens: [Token('RPAR', ')')]

# %%
unique_docs
# Out:
# [Document(page_content='A promise made must be a promise kept.', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='Happiness is the reward of virtue.', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='He who hath many friends hath none.', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='Before you heal the body you must first heal the mind', metadata={'author': 'aristotle', 'tags': 'ethics'}),
#  Document(page_content='You are what you repeatedly do', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Philosophy begins with wonder.', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Fortune favours the bold.', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='A friend is another I.', metadata={'author': 'aristotle', 'tags': None}),
#  Document(page_content='Happiness springs from doing good and helping others.', metadata={'author': 'plato', 'tags': 'ethics'}),
#  Document(page_content='Rules for Happiness: something to do, someone to love, something to hope for.', metadata={'author': 'kant', 'tags': 'love'}),
#  Document(page_content='A moral system valid for all is basically immoral.', metadata={'author': 'nietzsche', 'tags': None}),
#  Document(page_content='Philosophy can make people sick.', metadata={'author': 'aristotle', 'tags': 'politics'}),
#  Document(page_content='Do the right thing because it is right.', metadata={'author': 'kant', 'tags': 'ethics'})]
